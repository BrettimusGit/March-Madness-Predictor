# %% [markdown]
# # Imports

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from numpy import random
import pickle

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn import metrics

# %% [markdown]
# # Gather Data

# %%
#Season Stats
df_season_results = pd.read_csv("Data/MDataFiles_Stage2/MRegularSeasonDetailedResults.csv")
df_teams = pd.read_csv("Data/MDataFiles_Stage2/MTeams.csv")
df_teamSpellings = pd.read_csv("Data/MDataFiles_Stage2/MTeamSpellings.csv", sep='\,', engine='python')

#KenPom
df_kenPom_2016 = pd.read_csv("Data/kenPom_2016.csv")
df_kenPom_2017 = pd.read_csv("Data/kenPom_2017.csv")
df_kenPom_2018 = pd.read_csv("Data/kenPom_2018.csv")
df_kenPom_2019 = pd.read_csv("Data/kenPom_2019.csv")
df_kenPom_2020 = pd.read_csv("Data/kenPom_2020.csv")
df_kenPom_2021 = pd.read_csv("Data/kenPom_2021.csv")

ken_poms = [df_kenPom_2016, df_kenPom_2017, df_kenPom_2018, df_kenPom_2019, df_kenPom_2020, df_kenPom_2021]

# %% [markdown]
# # View Data

# %%
print(df_season_results.shape)
df_season_results.describe()
# Out:
# (96687, 34)
#              Season        DayNum       WTeamID        WScore       LTeamID  \
# count  96687.000000  96687.000000  96687.000000  96687.000000  96687.000000
# mean    2012.121857     71.173095   1287.397344     75.525758   1282.075067
# std        5.341686     35.469735    104.859678     11.080892    104.044707
# min     2003.000000      0.000000   1101.000000     34.000000   1101.000000
# 25%     2008.000000     40.000000   1198.000000     68.000000   1191.000000
# 50%     2012.000000     75.000000   1286.000000     75.000000   1281.000000
# 75%     2017.000000    102.000000   1379.000000     83.000000   1373.000000
# max     2021.000000    132.000000   1471.000000    144.000000   1471.000000
#
#              LScore         NumOT          WFGM          WFGA         WFGM3  \
# count  96687.000000  96687.000000  96687.000000  96687.000000  96687.000000
# mean      63.536111      0.068386     26.193842     55.378086      7.187616
# std       10.918545      0.305739      4.691261      7.536354      3.087554
# min       20.000000      0.000000     10.000000     27.000000      0.000000
# 25%       56.000000      0.000000     23.000000     50.000000      5.000000
# 50%       63.000000      0.000000     26.000000     55.000000      7.000000
# 75%       71.000000      0.000000     29.000000     60.000000      9.000000
# max      140.000000      6.000000     57.000000    103.000000     26.000000
#
#               WFGA3          WFTM          WFTA           WOR           WDR  \
# count  96687.000000  96687.000000  96687.000000  96687.000000  96687.000000
# mean      18.823658     15.950469     22.420956     10.748167     25.769328
# std        5.899900      6.244435      8.117183      4.136131      4.915575
# min        1.000000      0.000000      0.000000      0.000000      5.000000
# 25%       15.000000     11.000000     17.000000      8.000000     22.000000
# 50%       18.000000     16.000000     22.000000     10.000000     26.000000
# 75%       23.000000     20.000000     28.000000     13.000000     29.000000
# max       56.000000     48.000000     67.000000     38.000000     54.000000
#
#                WAst           WTO          WStl          WBlk           WPF  \
# count  96687.000000  96687.000000  96687.000000  96687.000000  96687.000000
# mean      14.720614     12.919803      6.985655      3.803521     16.913535
# std        4.412852      4.010368      3.109083      2.442920      4.979572
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%       12.000000     10.000000      5.000000      2.000000     14.000000
# 50%       14.000000     13.000000      7.000000      3.000000     17.000000
# 75%       17.000000     15.000000      9.000000      5.000000     20.000000
# max       41.000000     33.000000     26.000000     21.000000     41.000000
#
#                LFGM          LFGA         LFGM3         LFGA3          LFTM  \
# count  96687.000000  96687.000000  96687.000000  96687.000000  96687.000000
# mean      22.648236     56.527010      6.106085     19.757785     12.133472
# std        4.369835      7.645022      2.787803      6.007033      5.361011
# min        6.000000     26.000000      0.000000      1.000000      0.000000
# 25%       20.000000     51.000000      4.000000     16.000000      8.000000
# 50%       23.000000     56.000000      6.000000     19.000000     12.000000
# 75%       25.000000     61.000000      8.000000     23.000000     15.000000
# max       47.000000    106.000000     22.000000     59.000000     42.000000
#
#                LFTA           LOR           LDR          LAst           LTO  \
# count  96687.000000  96687.000000  96687.000000  96687.000000  96687.000000
# mean      17.924768     10.925130     21.724120     11.425135     14.243507
# std        7.128986      4.214315      4.549865      3.728191      4.389558
# min        0.000000      0.000000      4.000000      0.000000      0.000000
# 25%       13.000000      8.000000     19.000000      9.000000     11.000000
# 50%       17.000000     11.000000     22.000000     11.000000     14.000000
# 75%       22.000000     14.000000     25.000000     14.000000     17.000000
# max       61.000000     36.000000     49.000000     31.000000     41.000000
#
#                LStl          LBlk           LPF
# count  96687.000000  96687.000000  96687.000000
# mean       5.997869      2.866114     19.128642
# std        2.755827      2.029359      5.516740
# min        0.000000      0.000000      0.000000
# 25%        4.000000      1.000000     16.000000
# 50%        6.000000      3.000000     19.000000
# 75%        8.000000      4.000000     22.000000
# max       22.000000     18.000000     45.000000

# %%
df_season_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96687 entries, 0 to 96686
# Data columns (total 34 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   96687 non-null  int64
#  1   DayNum   96687 non-null  int64
#  2   WTeamID  96687 non-null  int64
#  3   WScore   96687 non-null  int64
#  4   LTeamID  96687 non-null  int64
#  5   LScore   96687 non-null  int64
#  6   WLoc     96687 non-null  object
#  7   NumOT    96687 non-null  int64
#  8   WFGM     96687 non-null  int64
#  9   WFGA     96687 non-null  int64
#  10  WFGM3    96687 non-null  int64
#  11  WFGA3    96687 non-null  int64
#  12  WFTM     96687 non-null  int64
#  13  WFTA     96687 non-null  int64
#  14  WOR      96687 non-null  int64
#  15  WDR      96687 non-null  int64
#  16  WAst     96687 non-null  int64
#  17  WTO      96687 non-null  int64
#  18  WStl     96687 non-null  int64
#  19  WBlk     96687 non-null  int64
#  20  WPF      96687 non-null  int64
#  21  LFGM     96687 non-null  int64
#  22  LFGA     96687 non-null  int64
#  23  LFGM3    96687 non-null  int64
#  24  LFGA3    96687 non-null  int64
#  25  LFTM     96687 non-null  int64
#  26  LFTA     96687 non-null  int64
#  27  LOR      96687 non-null  int64
#  28  LDR      96687 non-null  int64
#  29  LAst     96687 non-null  int64
#  30  LTO      96687 non-null  int64
#  31  LStl     96687 non-null  int64
#  32  LBlk     96687 non-null  int64
#  33  LPF      96687 non-null  int64
# dtypes: int64(33), object(1)
# memory usage: 25.1+ MB

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df_season_results.corr())

# %%
df_kenPom_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rk              357 non-null    int64
#  1   TeamName_Clean  357 non-null    object
#  2   AdjEM           357 non-null    float64
#  3   AdjO            357 non-null    float64
#  4   AdjD            357 non-null    float64
#  5   AdjT            357 non-null    float64
#  6   Luck            357 non-null    float64
#  7   SOS_AdjEM       357 non-null    float64
#  8   SOS_OppO        357 non-null    float64
#  9   SOS_OppD        357 non-null    float64
#  10  NCSOS_AdjEM     357 non-null    float64
#  11  Year            357 non-null    int64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 33.6+ KB

# %% [markdown]
# # Clean Data

# %%
for x in range(len(ken_poms)):
    ken_poms[x]["TeamName_Clean"] = ken_poms[x]["TeamName_Clean"].str.lower()
    ken_poms[x]["TeamName_Clean"] = ken_poms[x]["TeamName_Clean"].str.strip()

# %%
def kenPom_Clean(df):
    kp_df = pd.merge(df, df_teamSpellings, left_on=['TeamName_Clean'], right_on = ['TeamNameSpelling'], how = 'left')
    kp_df = kp_df.drop(['TeamNameSpelling'], axis=1)
    kp_df.dropna(axis=0, how='any', inplace=True)
    
    return kp_df

# %%
ken_poms = [df_kenPom_2016, df_kenPom_2017, df_kenPom_2018, df_kenPom_2019, df_kenPom_2020, df_kenPom_2021]

kp_df_2016 = kenPom_Clean(df_kenPom_2016)
kp_df_2017 = kenPom_Clean(df_kenPom_2017)
kp_df_2018 = kenPom_Clean(df_kenPom_2018)
kp_df_2019 = kenPom_Clean(df_kenPom_2019)
kp_df_2020 = kenPom_Clean(df_kenPom_2020)
kp_df_2021 = kenPom_Clean(df_kenPom_2021)

# %%
kp_df_2021
# Out:
#       Rk      TeamName_Clean  AdjEM   AdjO   AdjD  AdjT   Luck  SOS_AdjEM  \
# 0      1             gonzaga  36.48  126.4   89.9  73.8  0.022      11.35
# 1      2              baylor  33.87  125.0   91.1  67.4  0.046      13.25
# 2      3            michigan  29.67  117.6   87.9  66.6  0.007      16.44
# 3      4            illinois  29.06  118.0   88.9  70.5  0.022      18.17
# 4      5             houston  28.75  118.3   89.6  64.4  0.018       9.21
# ..   ...                 ...    ...    ...    ...   ...    ...        ...
# 349  350               idaho -23.01   90.6  113.6  66.8 -0.021       0.42
# 351  352        delaware st. -24.53   90.9  115.4  73.3 -0.064      -3.65
# 352  353  south carolina st. -25.23   87.2  112.4  71.6 -0.109      -4.49
# 353  354         alabama st. -25.94   84.4  110.3  70.8 -0.049     -14.36
# 355  356         chicago st. -29.85   88.3  118.1  67.5 -0.006       9.06
#
#      SOS_OppO  SOS_OppD  NCSOS_AdjEM  Year  TeamID
# 0       108.1      96.8         6.21  2021  1211.0
# 1       108.7      95.5        -2.83  2021  1124.0
# 2       111.7      95.3         2.51  2021  1276.0
# 3       112.3      94.1        10.44  2021  1228.0
# 4       105.7      96.5         2.11  2021  1222.0
# ..        ...       ...          ...   ...     ...
# 349     102.9     102.5        15.56  2021  1225.0
# 351      98.9     102.6         2.33  2021  1175.0
# 352      98.3     102.8         2.06  2021  1354.0
# 353      91.6     105.9       -99.00  2021  1106.0
# 355     106.6      97.6         9.06  2021  1152.0
#
# [341 rows x 13 columns]

# %%
def get_season(df, year):
    df = df_season_results.loc[df_season_results.Season == year].reset_index(drop=True)
    return df

# %%
df_2016 = get_season('df_2016', 2016)
df_2017 = get_season('df_2017', 2017)
df_2018 = get_season('df_2018', 2018)
df_2019 = get_season('df_2019', 2019)
df_2020 = get_season('df_2020', 2020)
df_2021 = get_season('df_2021', 2021)

# %%
def merge_kp(df, kp_df):
    df = pd.merge(df, kp_df, left_on=['WTeamID'], right_on=['TeamID'], how='left', validate='m:1')
    df.dropna(axis=0, how='any', inplace=True)
    df['Winning_Team'] = df['TeamName_Clean']
    
    cols = ['WTeamID', 'Winning_Team', 'WScore', 'AdjEM', 'AdjO', 'AdjD', 'AdjT', 'Luck',
         'SOS_AdjEM','SOS_OppO', 'SOS_OppD', 'NCSOS_AdjEM', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 
         'WFTM', 'WFTA', 'WOR', 'WDR','WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LTeamID', 
         'LScore', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA','LOR', 'LDR', 'LAst', 'LTO', 
         'LStl', 'LBlk', 'LPF']
    df = df[cols]
    
    df = pd.merge(df, kp_df, left_on=['LTeamID'], right_on=['TeamID'], how='left', validate='m:1')
    df.dropna(axis=0, how='any', inplace=True)
    df['Losing_Team'] = df['TeamName_Clean']
    
    cols = ['WTeamID', 'Winning_Team', 'WScore', 'AdjEM_x', 'AdjO_x', 'AdjD_x','AdjT_x', 'Luck_x', 
         'SOS_AdjEM_x', 'SOS_OppO_x', 'SOS_OppD_x','NCSOS_AdjEM_x', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3',
         'WFTM', 'WFTA','WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 
         'LTeamID', 'Losing_Team', 'LScore','AdjEM_y','AdjO_y', 'AdjD_y', 'AdjT_y', 'Luck_y', 
         'SOS_AdjEM_y', 'SOS_OppO_y','SOS_OppD_y', 'NCSOS_AdjEM_y', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 
         'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst','LTO', 'LStl', 'LBlk', 'LPF']
    
    df = df[cols]
    
    return df

# %%
df_2016 = merge_kp(df_2016, kp_df_2016)
df_2017 = merge_kp(df_2017, kp_df_2017)
df_2018 = merge_kp(df_2018, kp_df_2018)
df_2019 = merge_kp(df_2019, kp_df_2019)
df_2020 = merge_kp(df_2020, kp_df_2020)
df_2021 = merge_kp(df_2021, kp_df_2021)

# %%
df_2021.head()
# Out:
#    WTeamID       Winning_Team  WScore  AdjEM_x  AdjO_x  AdjD_x  AdjT_x  \
# 0     1101  abilene christian      70    10.11   101.7    91.6    69.3
# 1     1104            alabama      81    25.09   112.9    87.8    73.3
# 2     1111    appalachian st.      81    -4.71    98.4   103.1    65.5
# 3     1113        arizona st.      94     9.85   108.4    98.5    72.5
# 4     1114        little rock      71    -6.86    98.4   105.3    67.0
#
#    Luck_x  SOS_AdjEM_x  SOS_OppO_x  SOS_OppD_x  NCSOS_AdjEM_x  WFGM  WFGA  \
# 0   0.009        -5.43        99.4       104.8           4.93    20    49
# 1   0.020        14.80       110.1        95.3           9.45    30    77
# 2   0.039        -2.83       100.4       103.3           5.52    32    62
# 3   0.026        16.04       110.9        94.9           9.16    27    61
# 4  -0.040        -2.76        99.8       102.6           3.86    22    51
#
#    WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LTeamID  \
# 0     13     23    17    27    6   24    14   15     8     3    0     1190
# 1      7     31    14    20   19   31    11   10     8     3    0     1240
# 2      7     27    10    13   13   41    15   23     6     3   13     1354
# 3      6     20    34    46   13   22     9   12     7     4    0     1348
# 4      4     17    23    29   16   16     7   19    13     4    0     1341
#
#           Losing_Team  LScore  AdjEM_y  AdjO_y  AdjD_y  AdjT_y  Luck_y  \
# 0  east tennessee st.      47     3.99   103.2    99.2    65.4  -0.063
# 1    jacksonville st.      57     0.44   104.9   104.5    65.8   0.017
# 2  south carolina st.      61   -25.23    87.2   112.4    71.6  -0.109
# 3        rhode island      88     7.21   104.7    97.5    69.0  -0.109
# 4    prairie view a&m      66    -6.51    94.6   101.2    69.2   0.111
#
#    SOS_AdjEM_y  SOS_OppO_y  SOS_OppD_y  NCSOS_AdjEM_y  LFGM  LFGA  LFGM3  \
# 0         3.87       104.9       101.0           4.67    15    51      3
# 1        -2.68       101.1       103.8           4.66    19    69      9
# 2        -4.49        98.3       102.8           2.06    24    80      7
# 3         9.40       106.6        97.2          11.37    29    56      9
# 4       -13.88        93.3       107.2           7.32    27    55      8
#
#    LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0     21    14    17   11   27     5   22     6     2    0
# 1     32    10    17   18   28    10   20     5     2    0
# 2     32     6    11   12   18    12    9    13     0   14
# 3     18    21    35    7   26    14   16     8     2    0
# 4     21     4     4    7   15    14   24    12     1    0

# %% [markdown]
# # Model Building

# %%
drop_cols = ['Winning_Team', 'Losing_Team', 'WTeamID', 'LTeamID', 'LScore', 'WFGM', 'WFGM3', 
             'WFTM','LFGM', 'LFGM3', 'LFTM']

regress_df_2016 = df_2016.drop(drop_cols, axis=1)

regress_df_2017 = df_2017.drop(drop_cols, axis=1)

regress_df_2018 = df_2018.drop(drop_cols, axis=1)

regress_df_2019 = df_2019.drop(drop_cols, axis=1)

regress_df_2020 = df_2020.drop(drop_cols, axis=1)

regress_df_2021 = df_2021.drop(drop_cols, axis=1)

# %%
regress_df_2021.head()
# Out:
#    WScore  AdjEM_x  AdjO_x  AdjD_x  AdjT_x  Luck_x  SOS_AdjEM_x  SOS_OppO_x  \
# 0      70    10.11   101.7    91.6    69.3   0.009        -5.43        99.4
# 1      81    25.09   112.9    87.8    73.3   0.020        14.80       110.1
# 2      81    -4.71    98.4   103.1    65.5   0.039        -2.83       100.4
# 3      94     9.85   108.4    98.5    72.5   0.026        16.04       110.9
# 4      71    -6.86    98.4   105.3    67.0  -0.040        -2.76        99.8
#
#    SOS_OppD_x  NCSOS_AdjEM_x  WFGA  WFGA3  WFTA  WOR  WDR  WAst  WTO  WStl  \
# 0       104.8           4.93    49     23    27    6   24    14   15     8
# 1        95.3           9.45    77     31    20   19   31    11   10     8
# 2       103.3           5.52    62     27    13   13   41    15   23     6
# 3        94.9           9.16    61     20    46   13   22     9   12     7
# 4       102.6           3.86    51     17    29   16   16     7   19    13
#
#    WBlk  WPF  AdjEM_y  AdjO_y  AdjD_y  AdjT_y  Luck_y  SOS_AdjEM_y  \
# 0     3    0     3.99   103.2    99.2    65.4  -0.063         3.87
# 1     3    0     0.44   104.9   104.5    65.8   0.017        -2.68
# 2     3   13   -25.23    87.2   112.4    71.6  -0.109        -4.49
# 3     4    0     7.21   104.7    97.5    69.0  -0.109         9.40
# 4     4    0    -6.51    94.6   101.2    69.2   0.111       -13.88
#
#    SOS_OppO_y  SOS_OppD_y  NCSOS_AdjEM_y  LFGA  LFGA3  LFTA  LOR  LDR  LAst  \
# 0       104.9       101.0           4.67    51     21    17   11   27     5
# 1       101.1       103.8           4.66    69     32    17   18   28    10
# 2        98.3       102.8           2.06    80     32    11   12   18    12
# 3       106.6        97.2          11.37    56     18    35    7   26    14
# 4        93.3       107.2           7.32    55     21     4    7   15    14
#
#    LTO  LStl  LBlk  LPF
# 0   22     6     2    0
# 1   20     5     2    0
# 2    9    13     0   14
# 3   16     8     2    0
# 4   24    12     1    0

# %%
def in_sample_results(regression, y_train, in_preds):
    ev = metrics.explained_variance_score(y_train, in_preds)
    mae =metrics.mean_absolute_error(y_train, in_preds) 
    mse=metrics.mean_squared_error(y_train, in_preds) 
    r2=metrics.r2_score(y_train, in_preds)
    
    print(f'{regression}')
    print('----------------------------------------------')
    print('IN SAMPLE RESULTS')
    print('Explained Variance: ', ev)
    print('r2: ', r2)
    print('MAE: ', mae)
    print('MSE: ', mse)
    print('RMSE ', np.sqrt(mse))
    print('----------------------------------------------')

# %%
def out_sample_results(y_test, out_preds):
    ev = metrics.explained_variance_score(y_test, out_preds)
    mae =metrics.mean_absolute_error(y_test, out_preds) 
    mse=metrics.mean_squared_error(y_test, out_preds) 
    r2=metrics.r2_score(y_test, out_preds)
    
    print('----------------------------------------------')
    print('OUT SAMPLE RESULTS')
    print('Explained Variance: ', ev)
    print('r2: ', r2)
    print('MAE: ', mae)
    print('MSE: ', mse)
    print('RMSE ', np.sqrt(mse))
    print('----------------------------------------------')

# %% [markdown]
# ### Model Metrics for 2021

# %% [markdown]
# #### Train, Test, Split

# %%
target = regress_df_2021["WScore"]
features = regress_df_2021.drop(["WScore"], axis=1)

X = np.array(features)
y = np.array(target)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# ##### Linear Regressions

# %%
# train the model
reg = LinearRegression()
reg.fit(X_train, y_train)

#get predictions
in_sample_preds = reg.predict(X_train)
out_sample_preds = reg.predict(X_test)

#metric report
in_sample_results('Linear Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Linear Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8543453254660834
# r2:  0.8543453254660834
# MAE:  3.1625374951841994
# MSE:  16.070948122472767
# RMSE  4.008858705725704
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.8400926950789177
# r2:  0.8393095264244651
# MAE:  3.172217544058585
# MSE:  15.793721216384688
# RMSE  3.974131504666735
# ----------------------------------------------

# %%
# train the model
ridge = Ridge()
ridge.fit(X_train, y_train)

#get predictions
in_sample_preds = ridge.predict(X_train)
out_sample_preds = ridge.predict(X_test)

#metric report
in_sample_results('Ridge Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Ridge Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8543204859277439
# r2:  0.8543204859277439
# MAE:  3.1633205271709564
# MSE:  16.07368881674377
# RMSE  4.009200520894879
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.8400497791241596
# r2:  0.8392713615927193
# MAE:  3.172712404581014
# MSE:  15.79747230815417
# RMSE  3.974603415204361
# ----------------------------------------------

# %%
# train the model
lasso = Lasso()
lasso.fit(X_train, y_train)

#get predictions
in_sample_preds = lasso.predict(X_train)
out_sample_preds = lasso.predict(X_test)

#metric report
in_sample_results('Lasso Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Lasso Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8364332295442127
# r2:  0.8364332295442127
# MAE:  3.380140541605084
# MSE:  18.047296394481766
# RMSE  4.248210963980222
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.8215878285662097
# r2:  0.8206116324916715
# MAE:  3.3264292206920394
# MSE:  17.63147374481481
# RMSE  4.198984846937984
# ----------------------------------------------

# %%
# train the model
en = ElasticNet()
en.fit(X_train, y_train)

#get predictions
in_sample_preds = en.predict(X_train)
out_sample_preds = en.predict(X_test)

#metric report
in_sample_results('Elastic Net Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Elastic Net Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8443958919994856
# r2:  0.8443958919994856
# MAE:  3.28880318546274
# MSE:  17.168728400389323
# RMSE  4.143516429361578
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.8283612733542828
# r2:  0.8273020113196291
# MAE:  3.2761679266304986
# MSE:  16.973899118954392
# RMSE  4.1199392130169095
# ----------------------------------------------

# %% [markdown]
# ##### Tree Based Models

# %%
# train the model
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

#get predictions
in_sample_preds = dt.predict(X_train)
out_sample_preds = dt.predict(X_test)

#metric report
in_sample_results('Decision Tree Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Decision Tree Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  1.0
# r2:  1.0
# MAE:  0.0
# MSE:  0.0
# RMSE  0.0
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.12319559325143958
# r2:  0.12108050360452449
# MAE:  7.3902097902097905
# MSE:  86.38601398601399
# RMSE  9.294407672682214
# ----------------------------------------------

# %%
# train the model
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

#get predictions
in_sample_preds = rf.predict(X_train)
out_sample_preds = rf.predict(X_test)

#metric report
in_sample_results('Random Forest Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Random Forest Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.9500817828136242
# r2:  0.9500746459529984
# MAE:  1.8197340797760673
# MSE:  5.5085617914625615
# RMSE  2.347032550149776
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.6479426729147879
# r2:  0.646409111358248
# MAE:  4.724769230769231
# MSE:  34.753248251748246
# RMSE  5.895188567955079
# ----------------------------------------------

# %% [markdown]
# ##### Ada Boost

# %%
# train the model
ada = AdaBoostRegressor()
ada.fit(X_train, y_train)

#get predictions
in_sample_preds = ada.predict(X_train)
out_sample_preds = ada.predict(X_test)

#metric report
in_sample_results('Ada Boost Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Ada Boost Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.6535343558342925
# r2:  0.6520369213722634
# MAE:  5.00913692613116
# MSE:  38.39283979766893
# RMSE  6.196195590656329
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.6017733531816823
# r2:  0.593372719721982
# MAE:  5.07384663160639
# MSE:  39.96601516435825
# RMSE  6.321868012253835
# ----------------------------------------------

# %% [markdown]
# ##### Gradient Boosting

# %%
# train the model
gb = GradientBoostingRegressor()
gb.fit(X_train, y_train)

#get predictions
in_sample_preds = gb.predict(X_train)
out_sample_preds = gb.predict(X_test)

#metric report
in_sample_results('Gradient Boosting Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Gradient Boosting Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8352957502596051
# r2:  0.8352957502596051
# MAE:  3.40856645797045
# MSE:  18.172801261605407
# RMSE  4.262956868372633
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.7221333685717015
# r2:  0.7201247633244106
# MAE:  4.124211301894891
# MSE:  27.507987032884873
# RMSE  5.244805719269769
# ----------------------------------------------

# %%
# train the model
xgb = XGBRegressor()
xgb.fit(X_train, y_train)

#get predictions
in_sample_preds = xgb.predict(X_train)
out_sample_preds = xgb.predict(X_test)

#metric report
in_sample_results('XTREME Gradient Boosting Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# XTREME Gradient Boosting Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.9956141038413332
# r2:  0.9956141036573657
# MAE:  0.5019659185175965
# MSE:  0.4839220767789837
# RMSE  0.6956450796052421
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.6931815258516176
# r2:  0.692234718646979
# MAE:  4.370974896837781
# MSE:  30.249204857106474
# RMSE  5.49992771380738
# ----------------------------------------------
